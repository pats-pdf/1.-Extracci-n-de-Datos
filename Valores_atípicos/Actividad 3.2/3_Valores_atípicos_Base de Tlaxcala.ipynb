# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/TI3002C/blob/main/4_Valores_at%C3%ADpicos_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('Base_de_Tlaxcala_Sin_Nulos.csv')

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fecha de Alta  56 non-null     str
#  1   Mes Lead       56 non-null     int64
#  2   AgLead         56 non-null     str
#  3   Titulo         56 non-null     str
#  4   Nombre         56 non-null     str
#  5   Producto       56 non-null     str
#  6   Temperatura    56 non-null     str
#  7   Comentario     56 non-null     str
#  8   Asesor         56 non-null     str
#  9   Fuente         56 non-null     str
#  10  Origen         56 non-null     str
#  11  Estatus        56 non-null     str
# dtypes: int64(1), str(11)
# memory usage: 5.4 KB

# %%
#Revisamos los valores de Mes Lead

data["Mes Lead"].unique()
# Out:
# array([10])

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Fecha de Alta    0
# Mes Lead         0
# AgLead           0
# Titulo           0
# Nombre           0
# Producto         0
# Temperatura      0
# Comentario       0
# Asesor           0
# Fuente           0
# Origen           0
# Estatus          0
# dtype: int64

# %%
# Variables cuantitativas: no hay 

# Variables cualitativas: columnas 0 a 4 y 9 a 14
cualitativas = data.iloc[:, 0:12]

# %%
#no se realiza diagrama,ya que como no hay variables cuantitativas, no se pueden realizar diagramas de caja, ni limpiar valores atipicos

# %%
#Convertir DataFrame a CSV
data.to_csv("Base_de_Tlaxcala_Sin_Atípicos.csv")
